# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ## **Statistical Information and Sorting**

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().T
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.sort_values("tip").head()
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1              3.07
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2              6.30
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No  Sat  Dinner     1              7.25
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# 236       Matthew Myers  3543676378973965    Sat5032
# 92         Leah Ramirez  3508911676966392    Fri3780
# 111         Terri Jones  3559221007826887    Sat4801
# 0    Christy Cunningham  3560325168603410    Sun2959

# %%
df.sort_values(["tip", "size"]).head(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 75        10.51  1.25    Male     No   Sat  Dinner     2              5.26
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# ...

# %%
df.sort_values(["tip", "size"], ascending=False).head(10)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 239       29.03   5.92    Male     No   Sat  Dinner     3              9.68
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
#
#             Payer Name         CC Number Payment ID
# 170      Gregory Clark  5473850968388236    Sat1954
# ...

# %%
df.sort_values(["tip", "size"], ascending=[True, False]).head(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 75        10.51  1.25    Male     No   Sat  Dinner     2              5.26
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
#
#              Payer Name         CC Number Payment ID
# 92         Leah Ramirez  3508911676966392    Fri3780
# ...

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#             CC Number          Payer Name Payment ID   day  price_per_person  \
# 0    3560325168603410  Christy Cunningham    Sun2959   Sun              8.49
# 1    4478071379779230      Douglas Tucker    Sun4608   Sun              3.45
# 2    6011812112971322      Travis Walters    Sun4458   Sun              7.00
# 3    4676137647685994    Nathaniel Harris    Sun5260   Sun             11.84
# 4    4832732618637221        Tonya Carter    Sun2251   Sun              6.15
# ..                ...                 ...        ...   ...               ...
# 239  5296068606052842       Michael Avila    Sat2657   Sat              9.68
# 240  3506806155565404      Monica Sanders    Sat1766   Sat             13.59
# 241  6011891618747196          Keith Wong    Sat3880   Sat             11.34
# 242     4375220550950        Dennis Dixon      Sat17   Sat              8.91
# 243  3511451626698139     Michelle Hardin    Thur672  Thur              9.39
#
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#      total_bill   tip    time smoker  size     sex  price_per_person   day  \
# 0         16.99  1.01  Dinner     No     2  Female              8.49   Sun
# 1         10.34  1.66  Dinner     No     3    Male              3.45   Sun
# 2         21.01  3.50  Dinner     No     3    Male              7.00   Sun
# 3         23.68  3.31  Dinner     No     2    Male             11.84   Sun
# 4         24.59  3.61  Dinner     No     4  Female              6.15   Sun
# ..          ...   ...     ...    ...   ...     ...               ...   ...
# 239       29.03  5.92  Dinner     No     3    Male              9.68   Sat
# 240       27.18  2.00  Dinner    Yes     2  Female             13.59   Sat
# 241       22.67  2.00  Dinner    Yes     2    Male             11.34   Sat
# 242       17.82  1.75  Dinner     No     2    Male              8.91   Sat
# 243       18.78  3.00  Dinner     No     2  Female              9.39  Thur
#
#     Payment ID          Payer Name         CC Number
# ...

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.sort_index(axis=0, ascending=False).sort_values("tip")
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.sort_index(axis=1, ascending=True).sort_values("tip")
# Out:
#             CC Number          Payer Name Payment ID   day  price_per_person  \
# 67   4359488526995267       Tiffany Brock    Sat3455   Sat              3.07
# 236  3543676378973965       Matthew Myers    Sat5032   Sat              6.30
# 92   3508911676966392        Leah Ramirez    Fri3780   Fri              2.88
# 111  3559221007826887         Terri Jones    Sat4801   Sat              7.25
# 0    3560325168603410  Christy Cunningham    Sun2959   Sun              8.49
# ..                ...                 ...        ...   ...               ...
# 141  3526515703718508      Steven Carlson   Thur1025  Thur              5.72
# 59   6596453823950595         Brian Ortiz    Sat8139   Sat             12.07
# 23   3542584061609808      Lance Peterson     Sat239   Sat              9.86
# 212      676218815212     Alex Williamson    Sat4590   Sat             12.08
# 170  5473850968388236       Gregory Clark    Sat1954   Sat             16.94
#
# ...

# %% [markdown]
# ## Korelasyon

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df[["total_bill", "tip"]].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
df[["total_bill", "tip", "size"]].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# ## min(), max(), idxmax(), idxmin()

# %%
df["total_bill"].max()
# Out:
# 50.81

# %%
df["total_bill"].idxmax()
# Out:
# 170

# %%
df["total_bill"].argmaxx()
# Out:
# 170

# %%
df.iloc[[170]]
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3             16.94
#
#         Payer Name         CC Number Payment ID
# 170  Gregory Clark  5473850968388236    Sat1954

# %%
df.iloc[[df["total_bill"].idxmax()]]
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3             16.94
#
#         Payer Name         CC Number Payment ID
# 170  Gregory Clark  5473850968388236    Sat1954

# %%
df["total_bill"].min()
# Out:
# 3.07

# %%
df["total_bill"].idxmin()
# Out:
# 67

# %%
df.iloc[[df["total_bill"].idxmin()]]
# Out:
#     total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 67        3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
#
#        Payer Name         CC Number Payment ID
# 67  Tiffany Brock  4359488526995267    Sat3455

# %% [markdown]
# ## Single selections using iloc and DataFrame
# ### Rows:
# data.iloc[0] # first row of data frame (Aleshia Tomkiewicz) - Note a Series data type output.
#
# data.iloc[1] # second row of data frame (Evan Zigomalas)
#
# data.iloc[-1] # last row of data frame (Mi Richan)
#
# ### Columns:
# data.iloc[:,0] # first column of data frame (first_name)
#
# data.iloc[:,1] # second column of data frame (last_name)
#
# data.iloc[:,-1] # last column of data frame (id)

# %% [markdown]
# ## Multiple row and column selections using iloc and DataFrame
# data.iloc[0:5] # first five rows of dataframe
#
# data.iloc[:, 0:2] # first two columns of data frame with all rows
#
# data.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
#
# data.iloc[0:5, 5:8] # first 5 rows and 5th, 6th, 7th columns of data frame (county -> phone1).

# %% [markdown]
# ## Selecting rows with a boolean/conditional lookup

# %%
df.loc[(df["total_bill"]>5) & (df["size"]==1)].head()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 82        10.07  1.83  Female     No  Thur   Lunch     1             10.07
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1              8.58
#
#          Payer Name         CC Number Payment ID
# 82      Julie Moody      630413282843   Thur4909
# 111     Terri Jones  3559221007826887    Sat4801
# 222  Jason Lawrence  3505302934650403    Fri6624

# %%
df.loc[(df["total_bill"]>5) & (df["size"]==1)], ["price_per_person", "CC "]
# Out:
#      price_per_person         CC Number
# 82              10.07      630413282843
# 111              7.25  3559221007826887
# 222              8.58  3505302934650403

# %% [markdown]
# ## value_counts()

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df["smoker"].value_counts(normalize=True)
# Out:
# No     0.618852
# Yes    0.381148
# Name: smoker, dtype: float64

# %%
df["smoker"].value_counts(normalize=True, ascending=True)
# Out:
# Yes    0.381148
# No     0.618852
# Name: smoker, dtype: float64

# %%
df["size"].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
df["size"].value_counts(normalize=True, ascending=True)
# Out:
# 1    0.016393
# 6    0.016393
# 5    0.020492
# 4    0.151639
# 3    0.155738
# 2    0.639344
# Name: size, dtype: float64

# %% [markdown]
# ## replace

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df["time"].replace("Dinner","DN")
# Out:
# 0      DN
# 1      DN
# 2      DN
# 3      DN
# 4      DN
#        ..
# 239    DN
# 240    DN
# 241    DN
# 242    DN
# 243    DN
# Name: time, Length: 244, dtype: object

# %%
df["sex"].replace(["Female", "Male"], ["F", "M"])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df["sex"] = df["sex"].replace(["Female", "Male"], ["F", "M"])

# %%
df
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01   F     No   Sun  Dinner     2              8.49
# 1         10.34  1.66   M     No   Sun  Dinner     3              3.45
# 2         21.01  3.50   M     No   Sun  Dinner     3              7.00
# 3         23.68  3.31   M     No   Sun  Dinner     2             11.84
# 4         24.59  3.61   F     No   Sun  Dinner     4              6.15
# ..          ...   ...  ..    ...   ...     ...   ...               ...
# 239       29.03  5.92   M     No   Sat  Dinner     3              9.68
# 240       27.18  2.00   F    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00   M    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75   M     No   Sat  Dinner     2              8.91
# 243       18.78  3.00   F     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# ...

# %% [markdown]
# ## Unique

# %%
df["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df["time"].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df["time"].nunique()
# Out:
# 2

# %% [markdown]
# ## map

# %%
my_map = {"Dinner":"D", "Lunch":"L"}

# %%
df["time"] = df["time"].map(my_map)

# %%
df
# Out:
#      total_bill   tip sex smoker   day time  size  price_per_person  \
# 0         16.99  1.01   F     No   Sun    D     2              8.49
# 1         10.34  1.66   M     No   Sun    D     3              3.45
# 2         21.01  3.50   M     No   Sun    D     3              7.00
# 3         23.68  3.31   M     No   Sun    D     2             11.84
# 4         24.59  3.61   F     No   Sun    D     4              6.15
# ..          ...   ...  ..    ...   ...  ...   ...               ...
# 239       29.03  5.92   M     No   Sat    D     3              9.68
# 240       27.18  2.00   F    Yes   Sat    D     2             13.59
# 241       22.67  2.00   M    Yes   Sat    D     2             11.34
# 242       17.82  1.75   M     No   Sat    D     2              8.91
# 243       18.78  3.00   F     No  Thur    D     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# ...

# %% [markdown]
# ## Duplicates

# %%
df["size"].duplicated()
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 239     True
# 240     True
# 241     True
# 242     True
# 243     True
# Name: size, Length: 244, dtype: bool

# %%
simple_df = pd.DataFrame([1,2,2],['a','b','c'])
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %% [markdown]
# ## between

# %% [markdown]
# left: A scalar value that defines the left boundary
#
# right: A scalar value that defines the right boundary
#
# inclusive: A Boolean value which is True by default. If False, it excludes the two passed arguments while checking.

# %%
df["total_bill"].between(10, 20, inclusive="both")
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df["total_bill"].between(10, 20, inclusive="neither")].head()
# Out:
#     total_bill   tip sex smoker  day time  size  price_per_person  \
# 0        16.99  1.01   F     No  Sun    D     2              8.49
# 1        10.34  1.66   M     No  Sun    D     3              3.45
# 8        15.04  1.96   M     No  Sun    D     2              7.52
# 9        14.78  3.23   M     No  Sun    D     2              7.39
# 10       10.27  1.71   M     No  Sun    D     2              5.14
#
#             Payer Name         CC Number Payment ID
# 0   Christy Cunningham  3560325168603410    Sun2959
# 1       Douglas Tucker  4478071379779230    Sun4608
# 8      Joseph Mcdonald  3522866365840377    Sun6820
# 9        Jerome Abbott  3532124519049786    Sun3775
# 10       William Riley      566287581219    Sun2546

# %% [markdown]
# ## Sample

# %%
df.sample(n=5)
# Out:
#      total_bill   tip sex smoker   day time  size  price_per_person  \
# 63        18.29  3.76   M    Yes   Sat    D     4              4.57
# 145        8.35  1.50   F     No  Thur    L     2              4.18
# 183       23.17  6.50   M    Yes   Sun    D     4              5.79
# 234       15.53  3.00   M    Yes   Sat    D     2              7.76
# 188       18.15  3.50   F    Yes   Sun    D     3              6.05
#
#             Payer Name         CC Number Payment ID
# 63           Chad Hart      580171498976    Sat4178
# 145          Amy Young     4285454264477   Thur9331
# 183  Dr. Michael James     4718501859162    Sun6059
# 234      Tracy Douglas  4097938155941930    Sat7220
# 188     Glenda Wiggins      578329325307     Sun430

# %%
df.sample(frac=0.1)
# Out:
#      total_bill   tip sex smoker   day time  size  price_per_person  \
# 138       16.00  2.00   M    Yes  Thur    L     2              8.00
# 191       19.81  4.19   F    Yes  Thur    L     2              9.90
# 113       23.95  2.55   M     No   Sun    D     2             11.98
# 175       32.90  3.11   M    Yes   Sun    D     2             16.45
# 239       29.03  5.92   M     No   Sat    D     3              9.68
# 229       22.12  2.88   F    Yes   Sat    D     2             11.06
# 232       11.61  3.39   M     No   Sat    D     2              5.80
# 104       20.92  4.08   F     No   Sat    D     2             10.46
# 0         16.99  1.01   F     No   Sun    D     2              8.49
# 60        20.29  3.21   M    Yes   Sat    D     2             10.14
# 134       18.26  3.25   F     No  Thur    L     2              9.13
# 192       28.44  2.56   M    Yes  Thur    L     2             14.22
# 38        18.69  2.31   M     No   Sat    D     3              6.23
# ...

# %%
df.sample(n=5, axis=1)
# Out:
#             CC Number  size  price_per_person Payment ID   day
# 0    3560325168603410     2              8.49    Sun2959   Sun
# 1    4478071379779230     3              3.45    Sun4608   Sun
# 2    6011812112971322     3              7.00    Sun4458   Sun
# 3    4676137647685994     2             11.84    Sun5260   Sun
# 4    4832732618637221     4              6.15    Sun2251   Sun
# ..                ...   ...               ...        ...   ...
# 239  5296068606052842     3              9.68    Sat2657   Sat
# 240  3506806155565404     2             13.59    Sat1766   Sat
# 241  6011891618747196     2             11.34    Sat3880   Sat
# 242     4375220550950     2              8.91      Sat17   Sat
# 243  3511451626698139     2              9.39    Thur672  Thur
#
# [244 rows x 5 columns]

# %% [markdown]
# ## nlargest and nsmallest

# %%
df.nlargest(10, "tip")
# Out:
#      total_bill    tip sex smoker   day time  size  price_per_person  \
# 170       50.81  10.00   M    Yes   Sat    D     3             16.94
# 212       48.33   9.00   M     No   Sat    D     4             12.08
# 23        39.42   7.58   M     No   Sat    D     4              9.86
# 59        48.27   6.73   M     No   Sat    D     4             12.07
# 141       34.30   6.70   M     No  Thur    L     6              5.72
# 183       23.17   6.50   M    Yes   Sun    D     4              5.79
# 214       28.17   6.50   F    Yes   Sat    D     3              9.39
# 47        32.40   6.00   M     No   Sun    D     4              8.10
# 239       29.03   5.92   M     No   Sat    D     3              9.68
# 88        24.71   5.85   M     No  Thur    L     2             12.36
#
#             Payer Name         CC Number Payment ID
# 170      Gregory Clark  5473850968388236    Sat1954
# 212    Alex Williamson      676218815212    Sat4590
# ...

# %%
df.nlargest(5, "total_bill")
# Out:
#      total_bill    tip sex smoker  day time  size  price_per_person  \
# 170       50.81  10.00   M    Yes  Sat    D     3             16.94
# 212       48.33   9.00   M     No  Sat    D     4             12.08
# 59        48.27   6.73   M     No  Sat    D     4             12.07
# 156       48.17   5.00   M     No  Sun    D     6              8.03
# 182       45.35   3.50   M    Yes  Sun    D     3             15.12
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 59       Brian Ortiz  6596453823950595    Sat8139
# 156    Ryan Gonzales  3523151482063321    Sun7518
# 182     Jose Parsons  4112207559459910    Sun2337

# %%
df.nsmallest(5, "tip")
# Out:
#      total_bill   tip sex smoker  day time  size  price_per_person  \
# 67         3.07  1.00   F    Yes  Sat    D     1              3.07
# 92         5.75  1.00   F    Yes  Fri    D     2              2.88
# 111        7.25  1.00   F     No  Sat    D     1              7.25
# 236       12.60  1.00   M    Yes  Sat    D     2              6.30
# 0         16.99  1.01   F     No  Sun    D     2              8.49
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# 92         Leah Ramirez  3508911676966392    Fri3780
# 111         Terri Jones  3559221007826887    Sat4801
# 236       Matthew Myers  3543676378973965    Sat5032
# 0    Christy Cunningham  3560325168603410    Sun2959

# %% [markdown]
# # Missing Values

# %%
np.nan
# Out:
# nan

# %%
pd.NA

# %%
pd.NaT
# Out:
# NaT

# %%
np.nan == np. nan
# Out:
# False

# %%
np.nan is np. nan
# Out:
# True

# %%
my_var = np.nan

# %%
my_var is np. nan
# Out:
# True

# %%
df = pd.read_csv("movie_scores.csv")

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0
