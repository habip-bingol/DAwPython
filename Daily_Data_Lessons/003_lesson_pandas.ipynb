# %% [markdown]
# PANDAS

# %%
import numpy as np
import pandas as pd

# %%
help(pd.Series)

# %% [markdown]
# Creation of Series from lists

# %%
myindex = [ "USA", "Canada", "Mexico"]
mydata = [1776, 1867, 1821]

# %%
pd.Series(data=mydata)
# Out:
# 0    1776
# 1    1867
# 2    1821
# dtype: int64

# %%
pd.Series(data=mydata, index=myindex)
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# dtype: int64

# %%
pd.Series(mydata, myindex)
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# dtype: int64

# %%
my_ser = pd.Series(mydata, myindex)

# %%
my_ser[0]
# Out:
# 1776

# %%
my_ser["Canada"]
# Out:
# 1867

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating Series from Dictionaries

# %%
ages = {"Sam" : 5, "Frank" : 10, "Spike" : 7}

# %%
pd.Series(ages)
# Out:
# Sam       5
# Frank    10
# Spike     7
# dtype: int64

# %%
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
sales_q1 = pd.Series(q1)
sales_q2 = pd.Series(q2)

# %%
type(sales_q1)
# Out:
# pandas.core.series.Series

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q2
# Out:
# Brazil    100
# China     500
# India     210
# USA       260
# dtype: int64

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
sales_q1["Japan"]
# Out:
# 80

# %%
sales_q1.Japan
# Out:
# 80

# %%
sales_q2*2
# Out:
# Brazil     200
# China     1000
# India      420
# USA        520
# dtype: int64

# %%
sales_q2/10
# Out:
# Brazil    10.0
# China     50.0
# India     21.0
# USA       26.0
# dtype: float64

# %%
sales_q1+sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
sales_q1.add(sales_q2,fill_value=0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %% [markdown]
# DataFrames

# %%
#Creating DataFrame
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks']

# %%
df = pd.DataFrame(lst)

# %%
df
# Out:
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
data = {'Name':['Tom', 'nick', 'krish', 'jack'],
        'Age':[20, 21, 19, 18]}

# %%
dt = pd.DataFrame(data)

# %%
dt
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
emp = pd.DataFrame()

# %%
print(emp)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks']

lbl_indx = ['L1', 'L2', 'L3', 'L4', 'L5', 'L6', 'L7']
clm_indx = ["col1"]

# %%
df2 = pd.DataFrame(lst, lbl_indx, clm_indx)

# %%
df2
# Out:
#       col1
# L1   Geeks
# L2     For
# L3   Geeks
# L4      is
# L5  portal
# L6     for
# L7   Geeks

# %%
#creating a DataFrame from Python Objects

np.random.seed(101)
my_data = np.random.randint(0,101,(4,3))

# %%
my_data
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ['CA','NY','AZ','TX']
mycolumns = ['Jan','Feb','Mar']

# %%
df3 = pd.DataFrame(data=my_data)
df3
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df4 = pd.DataFrame(data=my_data, index=myindex)
df4
# Out:
#      0   1   2
# CA  95  11  81
# NY  70  63  87
# AZ  75   9  77
# TX  40   4  63

# %%
df5 = pd.DataFrame(data=my_data, index=myindex, columns=mycolumns)
df5
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int32
#  1   Feb     4 non-null      int32
#  2   Mar     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
dates = pd.date_range("20130101", periods=6)
print(dates)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
type(dates)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df = pd.DataFrame(np.random.randn(6, 4), index = dates, columns = list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.433331 -0.136614  0.882140 -0.377811
# 2013-01-02  0.146639  1.269122  0.307881 -0.606806
# 2013-01-03  0.919318 -1.196118  0.508945 -0.848440
# 2013-01-04  2.010793 -0.137610 -0.598269  0.028234
# 2013-01-05  0.392746 -1.441695  0.000323 -1.049912
# 2013-01-06 -0.229937 -1.283599 -2.711192 -1.522410

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %% [markdown]
# Reading a .csv file for a DataFrame

# %%
pwd
# Out:
# 'c:\\Users\\ASUS\\Desktop\\CLARUSWAY\\002-Data Science\\001_Dersler\\Data Analitics with Python\\daily_data'

# %%
df = pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df2 = pd.read_csv('c:\\Users\\ASUS\\Desktop\\CLARUSWAY\\002-Data Science\\001_Dersler\\Data Analitics with Python\\daily_data\\tips.csv')
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
len(df)
# Out:
# 244

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().T
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
#sorting by an axis
df.sort_index(axis=0, ascending=False)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#             CC Number          Payer Name Payment ID   day  price_per_person  \
# 0    3560325168603410  Christy Cunningham    Sun2959   Sun              8.49
# 1    4478071379779230      Douglas Tucker    Sun4608   Sun              3.45
# 2    6011812112971322      Travis Walters    Sun4458   Sun              7.00
# 3    4676137647685994    Nathaniel Harris    Sun5260   Sun             11.84
# 4    4832732618637221        Tonya Carter    Sun2251   Sun              6.15
# ..                ...                 ...        ...   ...               ...
# 239  5296068606052842       Michael Avila    Sat2657   Sat              9.68
# 240  3506806155565404      Monica Sanders    Sat1766   Sat             13.59
# 241  6011891618747196          Keith Wong    Sat3880   Sat             11.34
# 242     4375220550950        Dennis Dixon      Sat17   Sat              8.91
# 243  3511451626698139     Michelle Hardin    Thur672  Thur              9.39
#
# ...

# %%
df.sort_values(by=["tip"], ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.sort_values("total_bill", ascending=True).head()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51  2.00    Male     No  Thur   Lunch     2              3.76
#
#          Payer Name         CC Number Payment ID
# 67    Tiffany Brock  4359488526995267    Sat3455
# 92     Leah Ramirez  3508911676966392    Fri3780
# 111     Terri Jones  3559221007826887    Sat4801
# 172     Larry White    30432617123103    Sun9209
# 149  Daniel Robbins  4823139288341889   Thur6321

# %%
df.sort_values(["total_bill", "tip"])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51   2.00    Male     No  Thur   Lunch     2              3.76
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#           Payer Name         CC Number Payment ID
# ...

# %%
df.sort_values(["tip", "total_bill"], ascending=[True, False])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# Selection and Indexing

# %% [markdown]
# * Columns

# %%
employee = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}

# %%
df = pd.DataFrame(employee)
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Address', 'Qualification'], dtype='object')

# %%
df["Name"]
# Out:
# 0       Jai
# 1    Princi
# 2    Gaurav
# 3      Anuj
# Name: Name, dtype: object

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

# %%
col_name = ["Name", "Age"]

# %%
df[col_name]
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24
# 2  Gaurav   22
# 3    Anuj   32

# %%
type(df[col_name])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Name", "Age"]]
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24
# 2  Gaurav   22
# 3    Anuj   32

# %%
df[1:3]
# Out:
#      Name  Age    Address Qualification
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA

# %% [markdown]
#     loc()  #str label
#
#     iloc()  #numerical label

# %%
df.loc[2]
# Out:
# Name                Gaurav
# Age                     22
# Address          Allahabad
# Qualification          MCA
# Name: 2, dtype: object

# %%
df.loc[[0,2]]
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 2  Gaurav   22  Allahabad           MCA

# %%
df[["Name","Age"]][0:2]
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24

# %%
df[0:2][["Name","Age"]]
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24

# %%
df2 = pd.read_csv("tips.csv")
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df2[df2["tip"] > 3]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5         25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 7         26.88  3.12    Male     No  Sun  Dinner     4              6.72
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 219       30.14  3.09  Female    Yes  Sat  Dinner     4              7.54
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2              6.71
# 232       11.61  3.39    Male     No  Sat  Dinner     2              5.80
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
#
#            Payer Name         CC Number Payment ID
# ...

# %%
df2[df2["sex"]== "Male"]
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1         10.34  1.66  Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31  Male     No  Sun  Dinner     2             11.84
# 5         25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 6          8.77  2.00  Male     No  Sun  Dinner     2              4.38
# ..          ...   ...   ...    ...  ...     ...   ...               ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2              6.30
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2             16.42
# 239       29.03  5.92  Male     No  Sat  Dinner     3              9.68
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75  Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df2[(df2["day"]=="Sun") | (df2["day"] == "Thur")]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2              6.50
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2              8.20
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4              5.13
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3              5.49
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df2[(df2["smoker"]=="Yes") & (df2["sex"]=="Female")]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2             13.43
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2             12.64
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2              8.16
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2              5.68
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2              7.69
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3             14.77
# 103       22.42  3.48  Female    Yes   Sat  Dinner     2             11.21
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2              7.16
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2              8.76
# ...

# %%
#the notna() conditional function returns a True for each row the values are not an Null value
df2[df2["Payment ID"].notna()]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
day = ["Sun", "Sat", "Thur"]

# %%
#isin()

# %%
df2[df2["day"].isin(day)]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df2[df2["size"].isin([2,3])]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 6          8.77  2.00    Male     No   Sun  Dinner     2              4.38
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df2.iloc[5:10, 6:]
# Out:
#    size  price_per_person          Payer Name         CC Number Payment ID
# 5     4              6.32          Erik Smith   213140353657882    Sun9679
# 6     2              4.38  Kristopher Johnson  2223727524230344    Sun5985
# 7     4              6.72         Robert Buck  3514785077705092    Sun8157
# 8     2              7.52     Joseph Mcdonald  3522866365840377    Sun6820
# 9     2              7.39       Jerome Abbott  3532124519049786    Sun3775

# %%
df2.iloc[5:10, 6] = 1

# %%
df2.iloc[5:10,6:]
# Out:
#    size  price_per_person          Payer Name         CC Number Payment ID
# 5     1              6.32          Erik Smith   213140353657882    Sun9679
# 6     1              4.38  Kristopher Johnson  2223727524230344    Sun5985
# 7     1              6.72         Robert Buck  3514785077705092    Sun8157
# 8     1              7.52     Joseph Mcdonald  3522866365840377    Sun6820
# 9     1              7.39       Jerome Abbott  3532124519049786    Sun3775

# %%
df2.iloc[5:10, 6] = np.nan

# %%
df2.iloc[5:10,6:]
# Out:
#    size  price_per_person          Payer Name         CC Number Payment ID
# 5   NaN              6.32          Erik Smith   213140353657882    Sun9679
# 6   NaN              4.38  Kristopher Johnson  2223727524230344    Sun5985
# 7   NaN              6.72         Robert Buck  3514785077705092    Sun8157
# 8   NaN              7.52     Joseph Mcdonald  3522866365840377    Sun6820
# 9   NaN              7.39       Jerome Abbott  3532124519049786    Sun3775

# %%
df2[df2["size"].notna()].head(10)
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0        16.99  1.01  Female     No  Sun  Dinner   2.0              8.49
# 1        10.34  1.66    Male     No  Sun  Dinner   3.0              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner   3.0              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner   2.0             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner   4.0              6.15
# 10       10.27  1.71    Male     No  Sun  Dinner   2.0              5.14
# 11       35.26  5.00  Female     No  Sun  Dinner   4.0              8.82
# 12       15.42  1.57    Male     No  Sun  Dinner   2.0              7.71
# 13       18.43  3.00    Male     No  Sun  Dinner   4.0              4.61
# 14       14.83  3.02  Female     No  Sun  Dinner   2.0              7.42
#
#             Payer Name         CC Number Payment ID
# 0   Christy Cunningham  3560325168603410    Sun2959
# 1       Douglas Tucker  4478071379779230    Sun4608
# ...
