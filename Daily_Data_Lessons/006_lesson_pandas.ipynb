# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("mpg")

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.groupby("model_year").mean()
# Out:
#                   mpg  cylinders  displacement  horsepower       weight  \
# model_year
# 70          17.689655   6.758621    281.413793  147.827586  3372.793103
# 71          21.250000   5.571429    209.750000  107.037037  2995.428571
# 72          18.714286   5.821429    218.375000  120.178571  3237.714286
# 73          17.100000   6.375000    256.875000  130.475000  3419.025000
# 74          22.703704   5.259259    171.740741   94.230769  2877.925926
# 75          20.266667   5.600000    205.533333  101.066667  3176.800000
# 76          21.573529   5.647059    197.794118  101.117647  3078.735294
# 77          23.375000   5.464286    191.392857  105.071429  2997.357143
# 78          24.061111   5.361111    177.805556   99.694444  2861.805556
# 79          25.093103   5.827586    206.689655  101.206897  3055.344828
# 80          33.696552   4.137931    115.827586   77.481481  2436.655172
# 81          30.334483   4.620690    135.310345   81.035714  2522.931034
# ...

# %%
df.groupby("model_year").size()
# Out:
# model_year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# dtype: int64

# %%
df.groupby("cylinders").size()
# Out:
# cylinders
# 3      4
# 4    204
# 5      3
# 6     84
# 8    103
# dtype: int64

# %%
df.groupby("name").apply(lambda x : x.mode())
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# amc ambassador brougham 0  13.0        8.0         360.0       175.0  3821.0
# amc ambassador dpl      0  15.0        8.0         390.0       190.0  3850.0
# amc ambassador sst      0  17.0        8.0         304.0       150.0  3672.0
# amc concord             0  19.4        4.0         151.0        90.0  3003.0
#                         1  24.3        6.0         232.0         NaN  3210.0
# ...                         ...        ...           ...         ...     ...
# vw pickup               0  44.0        4.0          97.0        52.0  2130.0
# vw rabbit               0  29.0        4.0          90.0        70.0  1937.0
#                         1  41.5        NaN          98.0        76.0  2144.0
# vw rabbit c (diesel)    0  44.3        4.0          90.0        48.0  2085.0
# vw rabbit custom        0  31.9        4.0          89.0        71.0  1925.0
#
# ...

# %%
df.groupby("horsepower").apply(lambda x : x.mode())
# Out:
#                mpg  cylinders  displacement  horsepower  weight  acceleration  \
# horsepower
# 46.0       0  26.0        4.0          97.0        46.0  1835.0          20.5
#            1   NaN        NaN           NaN         NaN  1950.0          21.0
# 48.0       0  43.1        4.0          90.0        48.0  1985.0          21.5
#            1  43.4        NaN           NaN         NaN  2085.0          21.7
#            2  44.3        NaN           NaN         NaN  2335.0          23.7
# 49.0       0  29.0        4.0          68.0        49.0  1867.0          19.5
# 52.0       0  29.0        4.0          76.0        52.0  1649.0          16.5
#            1  31.0        NaN          78.0         NaN  1985.0          19.4
#            2  32.8        NaN          85.0         NaN  2035.0          22.2
#            3  44.0        NaN          97.0         NaN  2130.0          24.6
# 53.0       0  33.0        4.0          91.0        53.0  1795.0          17.4
# ...

# %%
df.groupby("cylinders").mean()
# Out:
#                  mpg  displacement  horsepower       weight  acceleration  \
# cylinders
# 3          20.550000     72.500000   99.250000  2398.500000     13.250000
# 4          29.286765    109.796569   78.281407  2308.127451     16.601471
# 5          27.366667    145.000000   82.333333  3103.333333     18.633333
# 6          19.985714    218.142857  101.506024  3198.226190     16.263095
# 8          14.963107    345.009709  158.300971  4114.718447     12.955340
#
#            model_year
# cylinders
# 3           75.500000
# 4           77.073529
# 5           79.000000
# 6           75.928571
# 8           73.902913

# %%
df.groupby("cylinders").mean().loc[3,:]
# Out:
# mpg               20.55
# displacement      72.50
# horsepower        99.25
# weight          2398.50
# acceleration      13.25
# model_year        75.50
# Name: 3, dtype: float64

# %%
df.groupby(["model_year", "cylinders"]).mean()
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 70         4          25.285714    107.000000   87.714286  2292.571429
#            6          20.500000    199.000000   91.750000  2710.500000
#            8          14.111111    367.555556  183.666667  3940.055556
# 71         4          27.461538    101.846154   77.583333  2056.384615
#            6          18.000000    243.375000   98.875000  3171.875000
#            8          13.428571    371.714286  166.857143  4537.714286
# 72         3          19.000000     70.000000   97.000000  2330.000000
#            4          23.428571    111.535714   85.142857  2382.642857
#            8          13.615385    344.846154  159.692308  4228.384615
# 73         3          18.000000     70.000000   90.000000  2124.000000
#            4          22.727273    109.272727   82.909091  2338.090909
#            6          19.000000    212.250000  102.125000  2917.125000
# ...

# %%
df.groupby(level=0).mean()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0        8.0         307.0       130.0  3504.0          12.0
# 1    15.0        8.0         350.0       165.0  3693.0          11.5
# 2    18.0        8.0         318.0       150.0  3436.0          11.0
# 3    16.0        8.0         304.0       150.0  3433.0          12.0
# 4    17.0        8.0         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0        4.0         140.0        86.0  2790.0          15.6
# 394  44.0        4.0          97.0        52.0  2130.0          24.6
# 395  32.0        4.0         135.0        84.0  2295.0          11.6
# 396  28.0        4.0         120.0        79.0  2625.0          18.6
# 397  31.0        4.0         119.0        82.0  2720.0          19.4
#
#      model_year
# 0          70.0
# 1          70.0
# 2          70.0
# 3          70.0
# 4          70.0
# ..          ...
# ...

# %%
df.groupby(["model_year", "cylinders"]).mean().index      #(level0, level1)
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
df.groupby(["model_year", "cylinders"]).mean().index.levels   #([level0], [level1])
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %%
df.groupby("origin").count()
# Out:
#         mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# europe   70         70            70          68      70            70
# japan    79         79            79          79      79            79
# usa     249        249           249         245     249           249
#
#         model_year  name
# origin
# europe          70    70
# japan           79    79
# usa            249   249

# %%
df.groupby(["origin", "name"]).count()
# Out:
#                               mpg  cylinders  displacement  horsepower  \
# origin name
# europe audi 100 ls              1          1             1           1
#        audi 100ls               2          2             2           2
#        audi 4000                1          1             1           1
#        audi 5000                1          1             1           1
#        audi 5000s (diesel)      1          1             1           1
# ...                           ...        ...           ...         ...
# usa    pontiac phoenix          2          2             2           2
#        pontiac phoenix lj       1          1             1           1
#        pontiac safari (sw)      1          1             1           1
#        pontiac sunbird coupe    1          1             1           1
#        pontiac ventura sj       1          1             1           1
#
#                               weight  acceleration  model_year
# origin name
# ...

# %%
df.groupby(["origin", "name"]).count().loc["europe"]
# Out:
#                                  mpg  cylinders  displacement  horsepower  \
# name
# audi 100 ls                        1          1             1           1
# audi 100ls                         2          2             2           2
# audi 4000                          1          1             1           1
# audi 5000                          1          1             1           1
# audi 5000s (diesel)                1          1             1           1
# audi fox                           1          1             1           1
# bmw 2002                           1          1             1           1
# bmw 320i                           1          1             1           1
# fiat 124 sport coupe               1          1             1           1
# fiat 124 tc                        1          1             1           1
# fiat 124b                          1          1             1           1
# fiat 128                           2          2             2           2
# ...

# %%
df.groupby(["origin", "name"]).count().loc["europe"].describe()
# Out:
#              mpg  cylinders  displacement  horsepower     weight  \
# count  58.000000  58.000000     58.000000   58.000000  58.000000
# mean    1.206897   1.206897      1.206897    1.172414   1.206897
# std     0.554365   0.554365      0.554365    0.596420   0.554365
# min     1.000000   1.000000      1.000000    0.000000   1.000000
# 25%     1.000000   1.000000      1.000000    1.000000   1.000000
# 50%     1.000000   1.000000      1.000000    1.000000   1.000000
# 75%     1.000000   1.000000      1.000000    1.000000   1.000000
# max     4.000000   4.000000      4.000000    4.000000   4.000000
#
#        acceleration  model_year
# count     58.000000   58.000000
# mean       1.206897    1.206897
# std        0.554365    0.554365
# min        1.000000    1.000000
# 25%        1.000000    1.000000
# 50%        1.000000    1.000000
# 75%        1.000000    1.000000
# max        4.000000    4.000000

# %%
df.groupby(["model_year", "cylinders"]).mean().loc[80]
# Out:
#               mpg  displacement  horsepower   weight  acceleration
# cylinders
# 3          23.700          70.0  100.000000  2420.00        12.500
# 4          34.612         111.0   74.043478  2360.08        17.144
# 5          36.400         121.0   67.000000  2950.00        19.900
# 6          25.900         196.5  111.000000  3145.50        15.050

# %%
df.groupby(["model_year", "cylinders"]).mean().loc[80,3]
# Out:
# mpg               23.7
# displacement      70.0
# horsepower       100.0
# weight          2420.0
# acceleration      12.5
# Name: (80, 3), dtype: float64

# %%
df.groupby(["model_year", "cylinders"]).mean().loc[75:80]
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 75         4          25.250000    114.833333   84.916667  2489.250000
#            6          17.583333    233.750000   96.750000  3398.333333
#            8          15.666667    330.500000  142.000000  4108.833333
# 76         4          26.766667    106.333333   75.600000  2306.600000
#            6          20.000000    221.400000   98.700000  3349.600000
#            8          14.666667    324.000000  146.333333  4064.666667
# 77         3          21.500000     80.000000  110.000000  2720.000000
#            4          29.107143    106.500000   78.785714  2205.071429
#            6          19.500000    220.400000  102.000000  3383.000000
#            8          16.000000    335.750000  152.375000  4177.500000
# 78         4          29.576471    112.117647   79.705882  2296.764706
#            5          20.300000    131.000000  103.000000  2830.000000
# ...

# %%
df.groupby(["model_year", "cylinders"]).mean().loc[[(79,4),(80,3)]]
# Out:
#                          mpg  displacement  horsepower       weight  \
# model_year cylinders
# 79         4          31.525    113.583333       75.75  2357.583333
# 80         3          23.700     70.000000      100.00  2420.000000
#
#                       acceleration
# model_year cylinders
# 79         4             15.991667
# 80         3             12.500000

# %%
df.groupby(["model_year", "cylinders"]).mean().loc[(79,4):(80,3)]
# Out:
#                          mpg  displacement  horsepower       weight  \
# model_year cylinders
# 79         4          31.525    113.583333       75.75  2357.583333
#            5          25.400    183.000000       77.00  3530.000000
#            6          22.950    205.666667      105.00  3025.833333
#            8          18.630    321.400000      131.90  3862.900000
# 80         3          23.700     70.000000      100.00  2420.000000
#
#                       acceleration
# model_year cylinders
# 79         4             15.991667
#            5             20.100000
#            6             15.433333
#            8             15.400000
# 80         3             12.500000

# %%
df.groupby(["model_year", "cylinders"]).mean()

# %%
mod_year_cyl = df.groupby(["model_year", "cylinders"]).mean()
mod_year_cyl
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 70         4          25.285714    107.000000   87.714286  2292.571429
#            6          20.500000    199.000000   91.750000  2710.500000
#            8          14.111111    367.555556  183.666667  3940.055556
# 71         4          27.461538    101.846154   77.583333  2056.384615
#            6          18.000000    243.375000   98.875000  3171.875000
#            8          13.428571    371.714286  166.857143  4537.714286
# 72         3          19.000000     70.000000   97.000000  2330.000000
#            4          23.428571    111.535714   85.142857  2382.642857
#            8          13.615385    344.846154  159.692308  4228.384615
# 73         3          18.000000     70.000000   90.000000  2124.000000
#            4          22.727273    109.272727   82.909091  2338.090909
#            6          19.000000    212.250000  102.125000  2917.125000
# ...

# %%
mod_year_cyl.swaplevel().head()
# Out:
#                             mpg  displacement  horsepower       weight  \
# cylinders model_year
# 4         70          25.285714    107.000000   87.714286  2292.571429
# 6         70          20.500000    199.000000   91.750000  2710.500000
# 8         70          14.111111    367.555556  183.666667  3940.055556
# 4         71          27.461538    101.846154   77.583333  2056.384615
# 6         71          18.000000    243.375000   98.875000  3171.875000
#
#                       acceleration
# cylinders model_year
# 4         70             16.000000
# 6         70             15.500000
# 8         70             11.194444
# 4         71             16.961538
# 6         71             14.750000

# %%
mod_year_cyl.xs(key=72, axis=0, level="model_year")
# Out:
#                  mpg  displacement  horsepower       weight  acceleration
# cylinders
# 3          19.000000     70.000000   97.000000  2330.000000     13.500000
# 4          23.428571    111.535714   85.142857  2382.642857     17.214286
# 8          13.615385    344.846154  159.692308  4228.384615     13.000000

# %%
mod_year_cyl.xs(key=4, axis=0, level="cylinders")
# Out:
#                   mpg  displacement  horsepower       weight  acceleration
# model_year
# 70          25.285714    107.000000   87.714286  2292.571429     16.000000
# 71          27.461538    101.846154   77.583333  2056.384615     16.961538
# 72          23.428571    111.535714   85.142857  2382.642857     17.214286
# 73          22.727273    109.272727   82.909091  2338.090909     17.136364
# 74          27.800000     96.533333   74.000000  2151.466667     16.400000
# 75          25.250000    114.833333   84.916667  2489.250000     15.833333
# 76          26.766667    106.333333   75.600000  2306.600000     16.866667
# 77          29.107143    106.500000   78.785714  2205.071429     16.064286
# 78          29.576471    112.117647   79.705882  2296.764706     16.282353
# 79          31.525000    113.583333   75.750000  2357.583333     15.991667
# 80          34.612000    111.000000   74.043478  2360.080000     17.144000
# ...

# %%
mod_year_cyl.xs(key=(72,3), axis=0, level=["model_year", "cylinders"])
# Out:
#                        mpg  displacement  horsepower  weight  acceleration
# model_year cylinders
# 72         3          19.0          70.0        97.0  2330.0          13.5

# %%
df[df["cylinders"].isin([5,6])].groupby(["model_year","cylinders"]).mean()
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 70         6          20.500000    199.000000   91.750000  2710.500000
# 71         6          18.000000    243.375000   98.875000  3171.875000
# 73         6          19.000000    212.250000  102.125000  2917.125000
# 74         6          17.857143    230.428571  101.666667  3320.000000
# 75         6          17.583333    233.750000   96.750000  3398.333333
# 76         6          20.000000    221.400000   98.700000  3349.600000
# 77         6          19.500000    220.400000  102.000000  3383.000000
# 78         5          20.300000    131.000000  103.000000  2830.000000
#            6          19.066667    213.250000  109.833333  3314.166667
# 79         5          25.400000    183.000000   77.000000  3530.000000
#            6          22.950000    205.666667  105.000000  3025.833333
# 80         5          36.400000    121.000000   67.000000  2950.000000
# ...

# %%
df[df["cylinders"].isin([5,6])].groupby(["cylinders","model_year"]).mean()
# Out:
#                             mpg  displacement  horsepower       weight  \
# cylinders model_year
# 5         78          20.300000    131.000000  103.000000  2830.000000
#           79          25.400000    183.000000   77.000000  3530.000000
#           80          36.400000    121.000000   67.000000  2950.000000
# 6         70          20.500000    199.000000   91.750000  2710.500000
#           71          18.000000    243.375000   98.875000  3171.875000
#           73          19.000000    212.250000  102.125000  2917.125000
#           74          17.857143    230.428571  101.666667  3320.000000
#           75          17.583333    233.750000   96.750000  3398.333333
#           76          20.000000    221.400000   98.700000  3349.600000
#           77          19.500000    220.400000  102.000000  3383.000000
#           78          19.066667    213.250000  109.833333  3314.166667
#           79          22.950000    205.666667  105.000000  3025.833333
# ...

# %%
df.groupby(["model_year", "cylinders"]).mean().sort_index()
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 70         4          25.285714    107.000000   87.714286  2292.571429
#            6          20.500000    199.000000   91.750000  2710.500000
#            8          14.111111    367.555556  183.666667  3940.055556
# 71         4          27.461538    101.846154   77.583333  2056.384615
#            6          18.000000    243.375000   98.875000  3171.875000
#            8          13.428571    371.714286  166.857143  4537.714286
# 72         3          19.000000     70.000000   97.000000  2330.000000
#            4          23.428571    111.535714   85.142857  2382.642857
#            8          13.615385    344.846154  159.692308  4228.384615
# 73         3          18.000000     70.000000   90.000000  2124.000000
#            4          22.727273    109.272727   82.909091  2338.090909
#            6          19.000000    212.250000  102.125000  2917.125000
# ...

# %%
df1 = pd.DataFrame({"a": [1, 2, 3, 4]}, index=['A', 'b', 'C', 'd'])
df1.sort_index()
# Out:
#    a
# A  1
# C  3
# b  2
# d  4

# %%
df1 = pd.DataFrame({"a": [1, 2, 3, 4]}, index=['A', 'b', 'C', 'd'])
df1.sort_index(key=lambda x: x.str.lower())
# Out:
#    a
# A  1
# b  2
# C  3
# d  4

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.sort_index(level="model_year")
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.sort_index(level="model_year", ascending=False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 397  31.0          4         119.0        82.0    2720          19.4
# 396  28.0          4         120.0        79.0    2625          18.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 393  27.0          4         140.0        86.0    2790          15.6
# ..    ...        ...           ...         ...     ...           ...
# 4    17.0          8         302.0       140.0    3449          10.5
# 3    16.0          8         304.0       150.0    3433          12.0
# 2    18.0          8         318.0       150.0    3436          11.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 0    18.0          8         307.0       130.0    3504          12.0
#
#      model_year  origin                       name
# 397          82     usa                 chevy s-10
# ...

# %%
df.sort_values(["model_year", "cylinders"], ascending=[True, False])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.groupby(["model_year", "cylinders"]).mean().sort_index(ascending=False)
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 82         6          28.333333    225.000000  102.333333  2931.666667
#            4          32.071429    118.571429   79.148148  2402.321429
# 81         8          26.600000    350.000000  105.000000  3725.000000
#            6          23.428571    184.000000  100.714286  3093.571429
#            4          32.814286    108.857143   72.950000  2275.476190
# 80         6          25.900000    196.500000  111.000000  3145.500000
#            5          36.400000    121.000000   67.000000  2950.000000
#            4          34.612000    111.000000   74.043478  2360.080000
#            3          23.700000     70.000000  100.000000  2420.000000
# 79         8          18.630000    321.400000  131.900000  3862.900000
#            6          22.950000    205.666667  105.000000  3025.833333
#            5          25.400000    183.000000   77.000000  3530.000000
# ...

# %%
df.groupby(["model_year", "cylinders"]).mean().sort_index(ascending=False, level=1)
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 81         8          26.600000    350.000000  105.000000  3725.000000
# 79         8          18.630000    321.400000  131.900000  3862.900000
# 78         8          19.050000    300.833333  135.500000  3563.333333
# 77         8          16.000000    335.750000  152.375000  4177.500000
# 76         8          14.666667    324.000000  146.333333  4064.666667
# 75         8          15.666667    330.500000  142.000000  4108.833333
# 74         8          14.200000    315.200000  146.000000  4438.400000
# 73         8          13.200000    365.250000  170.000000  4279.050000
# 72         8          13.615385    344.846154  159.692308  4228.384615
# 71         8          13.428571    371.714286  166.857143  4537.714286
# 70         8          14.111111    367.555556  183.666667  3940.055556
# 82         6          28.333333    225.000000  102.333333  2931.666667
# ...

# %%
df.groupby(["model_year", "cylinders"]).mean().sort_index(ascending=False, level=1).swaplevel()
# Out:
#                             mpg  displacement  horsepower       weight  \
# cylinders model_year
# 8         81          26.600000    350.000000  105.000000  3725.000000
#           79          18.630000    321.400000  131.900000  3862.900000
#           78          19.050000    300.833333  135.500000  3563.333333
#           77          16.000000    335.750000  152.375000  4177.500000
#           76          14.666667    324.000000  146.333333  4064.666667
#           75          15.666667    330.500000  142.000000  4108.833333
#           74          14.200000    315.200000  146.000000  4438.400000
#           73          13.200000    365.250000  170.000000  4279.050000
#           72          13.615385    344.846154  159.692308  4228.384615
#           71          13.428571    371.714286  166.857143  4537.714286
#           70          14.111111    367.555556  183.666667  3940.055556
# 6         82          28.333333    225.000000  102.333333  2931.666667
# ...

# %%
df.groupby(["model_year", "cylinders"]).mean().sort_index(ascending=False, level=1).swaplevel().loc[6]
# Out:
#                   mpg  displacement  horsepower       weight  acceleration
# model_year
# 82          28.333333    225.000000  102.333333  2931.666667     16.033333
# 81          23.428571    184.000000  100.714286  3093.571429     15.442857
# 80          25.900000    196.500000  111.000000  3145.500000     15.050000
# 79          22.950000    205.666667  105.000000  3025.833333     15.433333
# 78          19.066667    213.250000  109.833333  3314.166667     16.391667
# 77          19.500000    220.400000  102.000000  3383.000000     16.900000
# 76          20.000000    221.400000   98.700000  3349.600000     17.000000
# 75          17.583333    233.750000   96.750000  3398.333333     17.708333
# 74          17.857143    230.428571  101.666667  3320.000000     16.857143
# 73          19.000000    212.250000  102.125000  2917.125000     15.687500
# 71          18.000000    243.375000   98.875000  3171.875000     14.750000
# ...
